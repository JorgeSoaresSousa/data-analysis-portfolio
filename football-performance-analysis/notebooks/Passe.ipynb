# %%
import pandas as pd

df = pd.read_csv("passe.csv")

# %%
top5 = ["Porto", "Sporting CP", "Benfica", "Gil Vicente FC", "Famalicão"]
df = df[df["Squad"].isin(top5)]

# %%
df = df[[
    "Squad",
    "CmpTotal%",
    "CmpShort%",
    "CmpMedium%",
    "Cmp%Long",
    "DribleSucc%",
    "PrgCarries"
]]

# %%
df = df.rename(columns={
    "CmpTotal%": "pass_total_pct",
    "CmpShort%": "pass_short_pct",
    "CmpMedium%": "pass_medium_pct",
    "CmpLong%": "pass_long_pct",
    "DribleSucc%": "dribble_success_pct",
    "PrgCarries": "prog_carries"
})

# %%
df
# Out:
#              Squad  pass_total_pct  pass_short_pct  pass_medium_pct  Cmp%Long  \
# 3          Benfica            84.3            90.6             89.8      64.9
# 8        Famalicão            76.2            87.4             83.4      52.0
# 9   Gil Vicente FC            76.0            86.0             84.3      51.5
# 12           Porto            82.3            88.4             88.9      55.5
# 15     Sporting CP            84.8            90.5             89.5      63.3
#
#     dribble_success_pct  prog_carries
# 3                  50.9           254
# 8                  37.9           173
# 9                  42.3           145
# 12                 45.0           191
# 15                 48.0           269
